# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRxp-hsw61ck9cpt5ExZIUhvSGT5zYzoUJl_7xr7YF5qZeazC8393q2taqwkDvMxVirgFDJm1WX3uAC/pub?output=csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
males = df.loc[df['Gender']=='Male'].copy()
females = df.loc[df['Gender']=='Female'].copy()

# %%
females['Height'].head()
# Out:
# 5000    58.910732
# 5001    65.230013
# 5002    63.369004
# 5003    64.479997
# 5004    61.793096
# Name: Height, dtype: float64

# %%
ax = sns.histplot(x=females['Height'],stat='probability',kde=True)
ax.axvline(females['Height'].mean(), color='k')
ax.set_title("Female Height (Inches)");

# %% [markdown]
# # Manually Calculate Z-Scores

# %%
mean = females["Height"].mean()
std = females["Height"].std()
z_scores_manual = (females['Height'] -  mean)/std
z_scores_manual.head(3)
# Out:
# 5000   -1.779502
# 5001    0.564198
# 5002   -0.126014
# Name: Height, dtype: float64

# %% [markdown]
# # Use scipy.stats zscore function

# %%
## Calculating z-scores with scipy.stats.zscore
z_scores_scipy = stats.zscore(females['Height'])
z_scores_scipy[0:3]
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_13992\1794483626.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   z_scores_scipy[0:3]
# 5000   -1.779680
# 5001    0.564255
# 5002   -0.126027
# Name: Height, dtype: float64

# %% [markdown]
# # Sci-kit learn's StandardScaler

# %%
scaler = StandardScaler()
z_scores_scaler = scaler.fit_transform(females[['Height']])
z_scores_scaler[:3]
# Out:
# array([[-1.77967952],
#        [ 0.56425475],
#        [-0.12602672]])

# %% [markdown]
# # Plot a histogram with z-scores

# %%
## Plot a histogram with z-scores
ax = sns.histplot(x=z_scores_manual,stat='probability',kde=True)
ax.set_xlabel("z-Scores")
ax.set_title("Female Height z-Scores");
